# %% [markdown]
# <a href="https://colab.research.google.com/github/meta-llama/llama-recipes/blob/main/recipes/use_cases/LiveData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ## This demo app shows:
# * How to use LlamaIndex, an open source library to help you build custom data augmented LLM applications
# * How to ask Llama 3 questions about recent live data via the [Tavily](https://tavily.com) live search API

# %%
# !pip install llama-index 
# !pip install llama-index-core
# !pip install llama-index-llms-replicate
# !pip install llama-index-embeddings-huggingface
# !pip install tavily-python
# !pip install replicate
# Out:
# Requirement already satisfied: llama-index in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (0.11.21)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.20 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.11.21)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.2.2)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.53.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (3.10.10)
# Requirement already satisfied: dataclasses-json in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (2024.9.0)
# Requirement already satisfied: httpx in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (0.25.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (3.4.2)
# Requirement already satisfied: numpy<2.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.4)
# Requirement already satisfied: pandas in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.13)
# Requirement already satisfied: click in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.0.6)
# Requirement already satisfied: idna in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.10)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.2.2)
# Requirement already satisfied: packaging>=17.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.20->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (0.2.0)
# Requirement already satisfied: llama-index-core in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (0.11.21)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (3.10.10)
# Requirement already satisfied: dataclasses-json in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (2024.9.0)
# Requirement already satisfied: httpx in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (0.25.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (4.0.3)
# Requirement already satisfied: click in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core) (3.23.1)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core) (1.0.6)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core) (1.2.2)
# Requirement already satisfied: llama-index-llms-replicate in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-llms-replicate) (0.11.21)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.10.10)
# Requirement already satisfied: dataclasses-json in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2024.9.0)
# Requirement already satisfied: httpx in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.25.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.9.0)
# Requirement already satisfied: wrapt in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (4.0.3)
# Requirement already satisfied: click in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (8.1.7)
# Requirement already satisfied: joblib in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (3.23.1)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.0.6)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-replicate) (1.2.2)
# Requirement already satisfied: llama-index-embeddings-huggingface in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.26.2)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-embeddings-huggingface) (0.11.21)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: filelock in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10.10)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.0.36)
# Requirement already satisfied: dataclasses-json in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.25.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.46.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.6.0.dev20241031)
# Requirement already satisfied: scikit-learn in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.2)
# Requirement already satisfied: scipy in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: click in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: jinja2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.23.1)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.0.6)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.0.2)
# Requirement already satisfied: tavily-python in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: requests in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from tavily-python) (0.8.0)
# Requirement already satisfied: httpx in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from tavily-python) (0.25.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from tiktoken>=0.5.1->tavily-python) (2024.9.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->tavily-python) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->tavily-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->tavily-python) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from requests->tavily-python) (2024.8.30)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->tavily-python) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->tavily-python) (1.0.6)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx->tavily-python) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->tavily-python) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->tavily-python) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx->tavily-python) (4.12.2)
# Requirement already satisfied: replicate in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: httpx<1,>=0.21.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from replicate) (0.25.2)
# Requirement already satisfied: packaging in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from replicate) (24.1)
# Requirement already satisfied: pydantic>1.10.7 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from replicate) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from replicate) (4.12.2)
# Requirement already satisfied: anyio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx<1,>=0.21.0->replicate) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx<1,>=0.21.0->replicate) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx<1,>=0.21.0->replicate) (1.0.6)
# Requirement already satisfied: idna in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx<1,>=0.21.0->replicate) (3.10)
# Requirement already satisfied: sniffio in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpx<1,>=0.21.0->replicate) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from pydantic>1.10.7->replicate) (2.23.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/orangecloud/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.2.2)

# %% [markdown]
# You will be using [Replicate](https://replicate.com/meta/meta-llama-3-8b-instruct) to run the examples here. You will need to first sign in with Replicate with your github account, then create a free API token [here](https://replicate.com/account/api-tokens) that you can use for a while. You can also use other Llama 3 cloud providers such as [Groq](https://console.groq.com/), [Together](https://api.together.xyz/playground/language/meta-llama/Llama-3-8b-hf), or [Anyscale](https://app.endpoints.anyscale.com/playground) - see Section 2 of the Getting to Know Llama [notebook](https://github.com/meta-llama/llama-recipes/blob/main/recipes/quickstart/Getting_to_know_Llama.ipynb) for more information.
#
# If you'd like to run Llama 3 locally for the benefits of privacy, no cost or no rate limit (some Llama 3 hosting providers set limits for free plan of queries or tokens per second or minute), see [Running Llama Locally](https://github.com/meta-llama/llama-recipes/blob/main/recipes/quickstart/Running_Llama3_Anywhere/Running_Llama_on_Mac_Windows_Linux.ipynb).

# %%
from getpass import getpass
import os

REPLICATE_API_TOKEN = getpass()
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN

# %% [markdown]
# You'll set up the Llama 3 8b chat model from Replicate. You can also use Llama 3 70b model by replacing the `model` name with "meta/meta-llama-3-70b-instruct".

# %%
from llama_index.core import Settings, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.replicate import Replicate

Settings.llm = Replicate(
    model="meta/meta-llama-3-8b-instruct",
    temperature=0.0,
    additional_kwargs={"top_p": 1, "max_new_tokens": 500},
)

Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from llama_index.core import Settings, VectorStoreIndex
#       2 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#       3 from llama_index.llms.replicate import Replicate
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/__init__.py:19
#      15 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      17 # indices
#      18 # loading
# ---> 19 from llama_index.core.indices import (
#      20     ComposableGraph,
#      21     DocumentSummaryIndex,
#      22     GPTDocumentSummaryIndex,
#      23     GPTKeywordTableIndex,
#      24     GPTListIndex,
#      25     GPTRAKEKeywordTableIndex,
#      26     GPTSimpleKeywordTableIndex,
#      27     GPTTreeIndex,
#      28     GPTVectorStoreIndex,
#      29     KeywordTableIndex,
#      30     KnowledgeGraphIndex,
#      31     PropertyGraphIndex,
#      32     ListIndex,
#      33     RAKEKeywordTableIndex,
#      34     SimpleKeywordTableIndex,
#      35     SummaryIndex,
#      36     TreeIndex,
#      37     VectorStoreIndex,
#      38     load_graph_from_storage,
#      39     load_index_from_storage,
#      40     load_indices_from_storage,
#      41 )
#      43 # structured
#      44 from llama_index.core.indices.common.struct_store.base import (
#      45     SQLDocumentContextBuilder,
#      46 )
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/__init__.py:32
#      26 from llama_index.core.indices.list import GPTListIndex, ListIndex, SummaryIndex
#      27 from llama_index.core.indices.list.base import (
#      28     GPTListIndex,
#      29     ListIndex,
#      30     SummaryIndex,
#      31 )
# ---> 32 from llama_index.core.indices.loading import (
#      33     load_graph_from_storage,
#      34     load_index_from_storage,
#      35     load_indices_from_storage,
#      36 )
#      37 from llama_index.core.indices.multi_modal import MultiModalVectorStoreIndex
#      38 from llama_index.core.indices.struct_store.pandas import (
#      39     GPTPandasIndex,
#      40     PandasIndex,
#      41 )
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/loading.py:6
#       4 from llama_index.core.indices.base import BaseIndex
#       5 from llama_index.core.indices.composability.graph import ComposableGraph
# ----> 6 from llama_index.core.indices.registry import INDEX_STRUCT_TYPE_TO_INDEX_CLASS
#       7 from llama_index.core.storage.storage_context import StorageContext
#       9 logger = logging.getLogger(__name__)
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/registry.py:13
#      11 from llama_index.core.indices.list.base import SummaryIndex
#      12 from llama_index.core.indices.multi_modal import MultiModalVectorStoreIndex
# ---> 13 from llama_index.core.indices.property_graph import PropertyGraphIndex
#      14 from llama_index.core.indices.struct_store.pandas import PandasIndex
#      15 from llama_index.core.indices.struct_store.sql import SQLStructStoreIndex
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/property_graph/__init__.py:1
# ----> 1 from llama_index.core.indices.property_graph.base import PropertyGraphIndex
#       2 from llama_index.core.indices.property_graph.retriever import PGRetriever
#       3 from llama_index.core.indices.property_graph.sub_retrievers.base import BasePGRetriever
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/property_graph/base.py:17
#      15 from llama_index.core.vector_stores.simple import DEFAULT_VECTOR_STORE
#      16 from llama_index.core.indices.base import BaseIndex
# ---> 17 from llama_index.core.indices.property_graph.transformations import (
#      18     SimpleLLMPathExtractor,
#      19     ImplicitPathExtractor,
#      20 )
#      21 from llama_index.core.ingestion.pipeline import (
#      22     run_transformations,
#      23     arun_transformations,
#      24 )
#      25 from llama_index.core.graph_stores.types import (
#      26     LabelledNode,
#      27     Relation,
#      28     PropertyGraphStore,
#      29     TRIPLET_SOURCE_KEY,
#      30 )
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/property_graph/transformations/__init__.py:4
#       1 from llama_index.core.indices.property_graph.transformations.implicit import (
#       2     ImplicitPathExtractor,
#       3 )
# ----> 4 from llama_index.core.indices.property_graph.transformations.schema_llm import (
#       5     SchemaLLMPathExtractor,
#       6 )
#       7 from llama_index.core.indices.property_graph.transformations.simple_llm import (
#       8     SimpleLLMPathExtractor,
#       9 )
#      10 from llama_index.core.indices.property_graph.transformations.dynamic_llm import (
#      11     DynamicLLMPathExtractor,
#      12 )
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/property_graph/transformations/schema_llm.py:95
#      56 DEFAULT_VALIDATION_SCHEMA: List[Triple] = [
#      57     ("PRODUCT", "USED_BY", "PRODUCT"),
#      58     ("PRODUCT", "USED_FOR", "MARKET"),
#    (...)
#      83     ("LOCATION", "PART_OF", "LOCATION"),
#      84 ]
#      86 DEFAULT_SCHEMA_PATH_EXTRACT_PROMPT = PromptTemplate(
#      87     "Give the following text, extract the knowledge graph according to the provided schema. "
#      88     "Try to limit to the output {max_triplets_per_chunk} extracted paths.s\n"
#    (...)
#      91     "-------\n"
#      92 )
# ---> 95 class SchemaLLMPathExtractor(TransformComponent):
#      96     """
#      97     Extract paths from a graph using a schema.
#      98
#    (...)
#     124             The number of workers to use. Defaults to 4.
#     125     """
#     127     llm: LLM
#
# File ~/Desktop/PROJECTS/META/meta-llama_llama-recipes/.venv/lib/python3.10/site-packages/llama_index/core/indices/property_graph/transformations/schema_llm.py:141, in SchemaLLMPathExtractor()
#     134 possible_relation_props: Optional[List[str]]
#     135 strict: bool
#     137 def __init__(
#     138     self,
#     139     llm: LLM,
#     140     extract_prompt: Optional[Union[PromptTemplate, str]] = None,
# --> 141     possible_entities: Optional[TypeAlias] = None,
#     142     possible_entity_props: Optional[Union[List[str], List[Tuple[str, str]]]] = None,
#     143     possible_relations: Optional[TypeAlias] = None,
#     144     possible_relation_props: Optional[
#     145         Union[List[str], List[Tuple[str, str]]]
#     146     ] = None,
#     147     strict: bool = True,
#     148     kg_schema_cls: Any = None,
#     149     kg_validation_schema: Optional[Union[Dict[str, str], List[Triple]]] = None,
#     150     max_triplets_per_chunk: int = 10,
#     151     num_workers: int = 4,
#     152 ) -> None:
#     153     """Init params."""
#     154     if isinstance(extract_prompt, str):
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/typing.py:309, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     307 except TypeError:
#     308     pass  # All real errors (not unhashable args) are raised below.
# --> 309 return func(*args, **kwds)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/typing.py:400, in _SpecialForm.__getitem__(self, parameters)
#     398 @_tp_cache
#     399 def __getitem__(self, parameters):
# --> 400     return self._getitem(self, parameters)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/typing.py:525, in Optional(self, parameters)
#     519 @_SpecialForm
#     520 def Optional(self, parameters):
#     521     """Optional type.
#     522
#     523     Optional[X] is equivalent to Union[X, None].
#     524     """
# --> 525     arg = _type_check(parameters, f"{self} requires a single type.")
#     526     return Union[arg, type(None)]
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/typing.py:169, in _type_check(arg, msg, is_argument, module)
#     167     return arg
#     168 if isinstance(arg, _SpecialForm) or arg in (Generic, Protocol):
# --> 169     raise TypeError(f"Plain {arg} is not valid as type argument")
#     170 if isinstance(arg, (type, TypeVar, ForwardRef, types.UnionType, ParamSpec)):
#     171     return arg
#
# TypeError: Plain typing.TypeAlias is not valid as type argument

# %% [markdown]
# Next you will use the [Tavily](https://tavily.com/) search engine to augment the Llama 3's responses. To create a free trial Tavily Search API, sign in with your Google or Github account [here](https://app.tavily.com/sign-in).

# %%
from tavily import TavilyClient

TAVILY_API_KEY = getpass()
tavily = TavilyClient(api_key=TAVILY_API_KEY)

# %% [markdown]
# Do a live web search on "Llama 3 fine-tuning".

# %%
response = tavily.search(query="Llama 3 fine-tuning")
context = [{"url": obj["url"], "content": obj["content"]} for obj in response['results']]

# %%
context

# %% [markdown]
# Create documents based on the search results, index and save them to a vector store, then create a query engine.

# %%
from llama_index.core import Document

documents = [Document(text=ct['content']) for ct in context]
index = VectorStoreIndex.from_documents(documents)

query_engine = index.as_query_engine(streaming=True)

# %% [markdown]
# You are now ready to ask Llama 3 questions about the live data using the query engine.

# %%
response = query_engine.query("give me a summary")
response.print_response_stream()

# %%
query_engine.query("what's the latest about Llama 3 fine-tuning?").print_response_stream()

# %%
query_engine.query("tell me more about Llama 3 fine-tuning").print_response_stream()
